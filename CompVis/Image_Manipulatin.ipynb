# %% [markdown]
# <a href="https://colab.research.google.com/github/awinarko-hue/Latihan/blob/main/CompVis/Image_Manipulatin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hist_blue_channel = cv2.calcHist([originalImage],[0],None,[256],[0,256])
hist_green_channel = cv2.calcHist([originalImage],[1],None,[256],[0,256])
hist_red_channel = cv2.calcHist([originalImage],[2],None,[256],[0,256])


plt.plot(hist_blue_channel)
plt.plot(hist_green_channel)
plt.plot(hist_red_channel)
plt.show()

# %%
! pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# %%
originalImage = cv2.imread('sample_gambar.jpeg',cv2.IMREAD_UNCHANGED)
cv2_imshow(originalImage)
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1080 at 0x7F2FB0F3EBB0>

# %%
originalImage = cv2.imread('sample_gambar.jpeg',cv2.IMREAD_UNCHANGED)
cv2_imshow(originalImage)
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1080 at 0x7F2F81C80BB0>

# %%
image_resized_down = cv2.resize(originalImage,(200,200))
cv2_imshow(image_resized_down)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F2F81C80A00>

# %%
grayImage = cv2.cvtColor(image_resized_down,cv2.COLOR_BGR2GRAY);
hsvImage = cv2.cvtColor(image_resized_down,cv2.COLOR_BGR2HSV);
cv2_imshow(grayImage);
cv2_imshow(hsvImage);
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7F2FB1E4EBB0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F2F81C80EE0>

# %%
blue_chanel = originalImage[:,:,0]
row,col,depth = originalImage.shape
cv2_imshow(blue_chanel);
print(blue_chanel[0:10-1,0:10-1])
print ("rows = ",  row, "kolom = ", col , "kedalaman =", depth)
# Out:
# <PIL.Image.Image image mode=L size=1080x1080 at 0x7F2F6C4A8EB0>
# [[10 10 12 ... 21 24 26]
#  [11 11 13 ... 22 25 27]
#  [11 11 11 ... 24 27 29]
#  ...
#  [54 54 54 ... 87 87 87]
#  [54 54 54 ... 87 87 87]
#  [54 54 54 ... 87 87 87]]
# rows =  1080 kolom =  1080 kedalaman = 3

# %%
cv2.imwrite("/content/drive/MyDrive/sample_gambar_resized.jpeg", image_resized_down)
# Out:
# True

# %% [markdown]
# Membuat Menjadi BLUR

# %%
blurred = cv2.GaussianBlur(grayImage, (5, 5), 0)
cv2_imshow(blurred);
# Out:
# <PIL.Image.Image image mode=L size=200x200 at 0x7F2F6C4BEFD0>

# %% [markdown]
# Canny Edge Detection

# %%
# cols-1 and rows-1 are the coordinate limits.
M = cv2.getRotationMatrix2D(((cols-1)/2.0,(rows-1)/2.0),90,1)
rotated = cv2.warpAffine(originalImage,M,(cols,rows))

cv2_imshow(rotated);
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1080 at 0x7F2F6C316E20>

# %%
edges = cv2.Canny(blurred, 50, 200)


plt.subplot(121),plt.imshow(grayImage,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])


plt.show()
